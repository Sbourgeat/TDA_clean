# %%
# load necessary libraries
# %matplotlib inline
#%matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider, Button, RadioButtons
import os,time,subprocess,glob
from PIL import Image
import cripser as cr
import tcripser as tcr

# %%
from PIL import Image
import tifffile as TIF

# Import the tiff file with tifffile

img = TIF.imread('/Users/skumar/TDA/Cubical_complex/only_brain/256_female.tiff')
#img = Image.open(options.input)
img= img.max() - img

image = img / img.max()

# %%
X = np.array(image)

X.shape
plt.imshow(X[100])

# %%
# compute PH for the V-construction with the python wrapper (takes time)
start = time.time()
pd = cr.computePH(X)
print ("elapsed_time:{} sec".format(time.time() - start))
print("Betti numbers: ",[np.sum(pd[:,0] == i) for i in range(3)])
# Out:
# elapsed_time:34.45969009399414 sec
# Betti numbers:  [9106, 12063, 2436]

# %%
## plot persistent diagram using persim
# %matplotlib inline
import persim
pds = [pd[pd[:,0] == i] for i in range(3)]
persim.plot_diagrams([p[:,1:3] for p in pds])

# %%
XX= [p[:,1:3] for p in pds]

lifespan_0 = XX[0][0:-2,1] -XX[0][0:-2,0] 
lifespan_1 = XX[1][:,1] -XX[1][:,0] 
lifespan_2 = XX[2][:,1] -XX[2][:,0] 

Lifespans = [lifespan_0, lifespan_1, lifespan_2]
from scipy.stats import entropy

for i in Lifespans:
    print(np.exp(entropy(i, base=2)))
# Out:
# 162208.03879171654
# 270543.80260302237
# 23332.212428777962

# %%
from PIL import Image
import tifffile as TIF

# Import the tiff file with tifffile

img = TIF.imread('/Users/skumar/TDA/Cubical_complex/only_brain/256_female_2.tiff')
#img = Image.open(options.input)
img= img.max() - img

image = img / img.max()


X = np.array(image)

X.shape
plt.imshow(X[100])
plt.show()


# compute PH for the V-construction with the python wrapper (takes time)
start = time.time()
pd = cr.computePH(X)
print ("elapsed_time:{} sec".format(time.time() - start))
print("Betti numbers: ",[np.sum(pd[:,0] == i) for i in range(3)])



## plot persistent diagram using persim
# %matplotlib inline
import persim
pds = [pd[pd[:,0] == i] for i in range(3)]
persim.plot_diagrams([p[:,1:3] for p in pds])
# Out:
# elapsed_time:16.610114097595215 sec
# Betti numbers:  [9105, 12063, 2436]

# %%
XX= [p[:,1:3] for p in pds]

lifespan_0 = XX[0][0:-2,1] -XX[0][0:-2,0] 
lifespan_1 = XX[1][:,1] -XX[1][:,0] 
lifespan_2 = XX[2][:,1] -XX[2][:,0] 

Lifespans = [lifespan_0, lifespan_1, lifespan_2]
from scipy.stats import entropy

for i in Lifespans:
    print(np.exp(entropy(i, base=2)))
# Out:
# 162206.84832560105
# 270543.80260302237
# 23332.212428777962

# %%
from PIL import Image
import tifffile as TIF

# Import the tiff file with tifffile

img = TIF.imread('/Users/skumar/TDA/Cubical_complex/only_brain/309_female.tiff')
#img = Image.open(options.input)
img= img.max() - img

image = img / img.max()


X = np.array(image)

X.shape
plt.imshow(X[100])
plt.show()


# compute PH for the V-construction with the python wrapper (takes time)
start = time.time()
pd = cr.computePH(X)
print ("elapsed_time:{} sec".format(time.time() - start))
print("Betti numbers: ",[np.sum(pd[:,0] == i) for i in range(3)])



## plot persistent diagram using persim
# %matplotlib inline
import persim
pds = [pd[pd[:,0] == i] for i in range(3)]
persim.plot_diagrams([p[:,1:3] for p in pds])
# Out:
# elapsed_time:24.19365382194519 sec
# Betti numbers:  [8670, 11210, 2126]

# %%
XX= [p[:,1:3] for p in pds]

lifespan_0 = XX[0][0:-2,1] -XX[0][0:-2,0] 
lifespan_1 = XX[1][:,1] -XX[1][:,0] 
lifespan_2 = XX[2][:,1] -XX[2][:,0] 

Lifespans = [lifespan_0, lifespan_1, lifespan_2]
from scipy.stats import entropy

for i in Lifespans:
    print(np.exp(entropy(i, base=2)))
# Out:
# 80730.84218204362
# 161248.18793969112
# 11865.296279737062

# %%
from PIL import Image
import tifffile as TIF

# Import the tiff file with tifffile

img = TIF.imread('/Users/skumar/TDA/Cubical_complex/only_brain/32_female.tiff')
#img = Image.open(options.input)
img= img.max() - img

image = img / img.max()


X = np.array(image)

X.shape
plt.imshow(X[100])
plt.show()


# compute PH for the V-construction with the python wrapper (takes time)
start = time.time()
pd = cr.computePH(X)
print ("elapsed_time:{} sec".format(time.time() - start))
print("Betti numbers: ",[np.sum(pd[:,0] == i) for i in range(3)])



## plot persistent diagram using persim
# %matplotlib inline
import persim
pds = [pd[pd[:,0] == i] for i in range(3)]
persim.plot_diagrams([p[:,1:3] for p in pds])
# Out:
# elapsed_time:39.44728398323059 sec
# Betti numbers:  [13511, 18038, 3526]

# %%
XX= [p[:,1:3] for p in pds]

lifespan_0 = XX[0][0:-2,1] -XX[0][0:-2,0] 
lifespan_1 = XX[1][:,1] -XX[1][:,0] 
lifespan_2 = XX[2][:,1] -XX[2][:,0] 

Lifespans = [lifespan_0, lifespan_1, lifespan_2]
from scipy.stats import entropy

for i in Lifespans:
    print(np.exp(entropy(i, base=2)))
# Out:
# 222582.07758746718
# 336538.580160705
# 25186.120290889365
